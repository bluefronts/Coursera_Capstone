# %%
#!conda install -c conda-forge geopy --yes
import requests
import pandas as pd
import numpy as np
import json
from bs4 import BeautifulSoup as bs
from geopy.geocoders import Nominatim

# %% [markdown]
# ## We try to get Chinatown location first

# %%
with open('newyork_data.json') as json_data:
    newyork_data = json.load(json_data)

# %%
neighborhoods_data = newyork_data['features']
#take a look at structure in feature
newyork_data['features'][1]
# Out:
# {'type': 'Feature',
#  'id': 'nyu_2451_34572.2',
#  'geometry': {'type': 'Point',
#   'coordinates': [-73.82993910812398, 40.87429419303012]},
#  'geometry_name': 'geom',
#  'properties': {'name': 'Co-op City',
#   'stacked': 2,
#   'annoline1': 'Co-op',
#   'annoline2': 'City',
#   'annoline3': None,
#   'annoangle': 0.0,
#   'borough': 'Bronx',
#   'bbox': [-73.82993910812398,
#    40.87429419303012,
#    -73.82993910812398,
#    40.87429419303012]}}

# %%
# define the dataframe columns
column_names = ['Borough', 'Neighborhood', 'Latitude', 'Longitude'] 

# instantiate the dataframe
neighborhoods = pd.DataFrame(columns=column_names)

# %%
#get all info into dataframe
for x in neighborhoods_data:
    borough = x['properties']['borough'] 
    neighborhood_name = x['properties']['name']
        
    neighborhood_latlon = x['geometry']['coordinates']
    neighborhood_lat = neighborhood_latlon[1]
    neighborhood_lon = neighborhood_latlon[0]
    
    neighborhoods = neighborhoods.append({'Borough': borough,
                                          'Neighborhood': neighborhood_name,
                                          'Latitude': neighborhood_lat,
                                          'Longitude': neighborhood_lon}, ignore_index=True)

# %%
neighborhoods.head(20)
# Out:
#       Borough        Neighborhood   Latitude  Longitude
# 0       Bronx           Wakefield  40.894705 -73.847201
# 1       Bronx          Co-op City  40.874294 -73.829939
# 2       Bronx         Eastchester  40.887556 -73.827806
# 3       Bronx           Fieldston  40.895437 -73.905643
# 4       Bronx           Riverdale  40.890834 -73.912585
# 5       Bronx         Kingsbridge  40.881687 -73.902818
# 6   Manhattan         Marble Hill  40.876551 -73.910660
# 7       Bronx            Woodlawn  40.898273 -73.867315
# 8       Bronx             Norwood  40.877224 -73.879391
# 9       Bronx      Williamsbridge  40.881039 -73.857446
# 10      Bronx          Baychester  40.866858 -73.835798
# 11      Bronx      Pelham Parkway  40.857413 -73.854756
# 12      Bronx         City Island  40.847247 -73.786488
# 13      Bronx        Bedford Park  40.870185 -73.885512
# 14      Bronx  University Heights  40.855727 -73.910416
# 15      Bronx      Morris Heights  40.847898 -73.919672
# 16      Bronx             Fordham  40.860997 -73.896427
# 17      Bronx        East Tremont  40.842696 -73.887356
# 18      Bronx          West Farms  40.839475 -73.877745
# 19      Bronx        High  Bridge  40.836623 -73.926102

# %%
neighborhoods.loc[neighborhoods['Neighborhood']=='Chinatown']
# Out:
#        Borough Neighborhood   Latitude  Longitude
# 100  Manhattan    Chinatown  40.715618 -73.994279

# %%
#get chinatown latitude and longtitude
latitude=neighborhoods.iloc[100,-2]
longitude=neighborhoods.iloc[100,-1]
print('Chinatown in New York is at ({},{})'.format(latitude,longitude))
# Out:
# Chinatown in New York is at (40.71561842231432,-73.99427936255978)

# %%
#next, use explore function in Foursquare API to find 100 Chinese Restaurant

# %%
# we can use parameter 'categoryId' to filter all Chinese Restaurant
CLIENT_ID='0BPBI1NPMF11CVC2IP2AOOGYLSCFZIZCHTN4UKHQJCCFVHFN'
CLIENT_SECRET='5S1BMTKQ50OSBHWTO1EAHRBTOYBXPGZLIR1G1SZUFIBU103F'
VERSION='20200701'
radius=2000
LIMIT=300
categoryId='4bf58dd8d48988d145941735'
url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}&categoryId={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, radius, LIMIT,categoryId)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?client_id=0BPBI1NPMF11CVC2IP2AOOGYLSCFZIZCHTN4UKHQJCCFVHFN&client_secret=5S1BMTKQ50OSBHWTO1EAHRBTOYBXPGZLIR1G1SZUFIBU103F&ll=40.71561842231432,-73.99427936255978&v=20200701&radius=2000&limit=300&categoryId=4bf58dd8d48988d145941735'

# %%
results = requests.get(url).json()

# %%
df_init=[]

# %%
columnname=['NAME','ID','ADDRESS']

# %%
df_init=pd.DataFrame(columns=columnname)
df_init
# Out:
# Empty DataFrame
# Columns: [NAME, ID, ADDRESS]
# Index: []

# %%
#use for loop to add all results into dataframe, note that due to limit by API, we can only retrive 100 spots at one time
for item in results['response']['groups'][0]['items']:
    NAME=item['venue']['name']
    ID=item['venue']['id']
    try:
        ADDRESS=item['venue']['location']['address']
    except:
        ADDRESS='N/A'
    df_init=df_init.append({'NAME':NAME,'ID':ID,'ADDRESS':ADDRESS},ignore_index=True)
df_init
# Out:
#                                  NAME                        ID  \
# 0                    Big Wong King 大旺  3fd66200f964a520ede41ee3
# 1               Great N.Y. Noodletown  3fd66200f964a520b1ea1ee3
# 2                Mission Chinese Food  4fa89bb2e4b0bad89524b84a
# 3                  Nom Wah Tea Parlor  49f220a3f964a520ee691fe3
# 4   Wah Fung Number 1 Fast Food 華豐快飯店  4a96bf8ff964a520ce2620e3
# ..                                ...                       ...
# 95                           Ho Foods  5a06749bd3cce816fb29ce65
# 96                     99 Favor Taste  5974056d4b78c57f67d093b4
# 97            Golden Fung Wong Bakery  49fd0549f964a520ff6e1fe3
# 98                 New Kim Tuong 金祥飯店  4c50ba549d642d7fecd95ddc
# 99              Sushumai Asian Fusion  59b35fc1fdb9a771a66b3a48
#
#               ADDRESS
# 0          67 Mott St
# 1           28 Bowery
# 2      171 E Broadway
# 3        13 Doyers St
# 4      79 Chrystie St
# ..                ...
# 95       110 E 7th St
# 96  37 Saint Marks Pl
# 97         41 Mott St
# 98     83 Chrystie St
# 99     112 Stanton St
#
# [100 rows x 3 columns]

# %% [markdown]
# #now we use id in each row and Premium endpoint of Foursquare API ' https://api.foursquare.com/v2/venues/VENUE_ID' to search for categories,price tier,likes count,rating,
# #ratingSignals,likes count,popular timeframe,latitude,longitude
# ## 1. we use a function to find out Chinese Restaurant and Non-Chinese Restaurant
# ## 2. we use first for loop to filter the most liked tip
# ## 3. we use second for loop to combine all popular timeframe into one,cos timeframes can be more than one

# %%
# we design a function to find out Chinese Restaurant and Non-Chinese Restaurant,cos one venue can have more than one categories, so we use for loop to filter all categories
def if_cnr(venue_input):
    
        list1=[]
        try:
            for item in venue_input['response']['groups'][0]['items']:
                x=('4bf58dd8d48988d145941735' in item['venue']['categories'][0]['id'])
                list1.append(x)
            if True in list1:
                return 'Chinese Restaurant'
            else:
                return 'Non-Chinese Restaurant'
        except:
            return 'N/A'

# %%
# results['response']['groups'][0]['items'][0]['venue']['categories'][0]['id']
# Out:
# '4bf58dd8d48988d145941735'

# %%
# testing tips API
url_tips='https://api.foursquare.com/v2/venues/{}/tips?&sort=popular&client_id={}&client_secret={}&v={}'.format('5a06749bd3cce816fb29ce65',CLIENT_ID, CLIENT_SECRET,VERSION)
print(url_tips)
tips_detail=requests.get(url_tips).json()
tips_detail['response']['tips']['items'][0]['agreeCount']
# Out:
# https://api.foursquare.com/v2/venues/5a06749bd3cce816fb29ce65/tips?&sort=popular&client_id=0BPBI1NPMF11CVC2IP2AOOGYLSCFZIZCHTN4UKHQJCCFVHFN&client_secret=5S1BMTKQ50OSBHWTO1EAHRBTOYBXPGZLIR1G1SZUFIBU103F&v=20200701
# 5

# %%
#1. we use two premium API-- venue details and venue tips
#2. we use first for loop to filter the most liked tip
#3. we use second for loop to combine all popular timeframe into one,cos timeframes can be more than one
#4. Due to venues details are not the same, for example, some have tips some don't, so we use try/except to catach some details in case errors occur

df=df_init
df['Price_Tier']=''
df['Likes_Count']=''
df['Rating']=''
df['Rating_Signals']=''
df['Tips']=''
df['Agree_Count']=''
df['Polular_Timeframe_Today']=''
df['Latitude']=''
df['Longitude']=''

for index,row in df_init.iterrows():
    id_venue=row['ID']
    url_venue='https://api.foursquare.com/v2/venues/{}?&client_id={}&client_secret={}&v={}'.format(id_venue,CLIENT_ID, CLIENT_SECRET,VERSION)
    url_tips='https://api.foursquare.com/v2/venues/{}/tips?&sort=popular&client_id={}&client_secret={}&v={}'.format(id_venue,CLIENT_ID, CLIENT_SECRET,VERSION)
    venue_detail=requests.get(url_venue).json()
    tips_detail=requests.get(url_tips).json()

    try:
        Price_Tier=venue_detail['response']['venue']['price']['tier']
    except:
        Price_Tier='N/A'
    try:
        Likes_Count=venue_detail['response']['venue']['likes']['count']
    except:
        Likes_Count='N/A'
    try:
        Rating=venue_detail['response']['venue']['rating']
    except:
        Rating='N/A'
    try:
        Rating_Signals=venue_detail['response']['venue']['ratingSignals']
    except:
        Rating_Signals='N/A'
    #use API parameter 'sort=popular' to retrive most liked tips
    Tips=''
    Agree_Count=0
    try:
        Tips=tips_detail['response']['tips']['items'][0]['text']
        Agree_Count=tips_detail['response']['tips']['items'][0]['agreeCount']
    except:
        Agree_Count='N/A'
        Tips=='N/A'

    #deal with today's popular timeframes,combine all timeframe into one
    Polular_Timeframe_Today=''
    try:
        for y in venue_detail['response']['venue']['popular']['timeframes'][0]['open']:
            Polular_Timeframe_Today+=y['renderedTime']
    except:
        Polular_Timeframe_Today='N/A'
    
    try:
        Latitude=venue_detail['response']['venue']['location']['lat']
        Longitude=venue_detail['response']['venue']['location']['lng']
    except:
        Latitude='N/A'
        Longitude='N/A'
    #all retrived data into columns
    
    row['Price_Tier']=Price_Tier
    row['Likes_Count']=Likes_Count
    row['Rating']=Rating
    row['Rating_Signals']=Rating_Signals
    row['Tips']=Tips
    row['Agree_Count']=Agree_Count
    row['Polular_Timeframe_Today']=Polular_Timeframe_Today
    row['Latitude']=Latitude
    row['Longitude']=Longitude

# %%
# show dataframe
df
# Out:
#                                  NAME                        ID  \
# 0                    Big Wong King 大旺  3fd66200f964a520ede41ee3
# 1               Great N.Y. Noodletown  3fd66200f964a520b1ea1ee3
# 2                Mission Chinese Food  4fa89bb2e4b0bad89524b84a
# 3                  Nom Wah Tea Parlor  49f220a3f964a520ee691fe3
# 4   Wah Fung Number 1 Fast Food 華豐快飯店  4a96bf8ff964a520ce2620e3
# ..                                ...                       ...
# 95                           Ho Foods  5a06749bd3cce816fb29ce65
# 96                     99 Favor Taste  5974056d4b78c57f67d093b4
# 97            Golden Fung Wong Bakery  49fd0549f964a520ff6e1fe3
# 98                 New Kim Tuong 金祥飯店  4c50ba549d642d7fecd95ddc
# 99              Sushumai Asian Fusion  59b35fc1fdb9a771a66b3a48
#
#               ADDRESS Category Price_Tier Likes_Count Rating Rating_Signals  \
# 0          67 Mott St                   1         422    8.4            646
# 1           28 Bowery                   1         547      8            910
# 2      171 E Broadway                   3         945    8.1           1374
# 3        13 Doyers St                   1        1258    8.4           1790
# 4      79 Chrystie St                   1         192    8.5            281
# ..                ...      ...        ...         ...    ...            ...
# 95       110 E 7th St                 N/A         N/A    N/A            N/A
# 96  37 Saint Marks Pl                 N/A         N/A    N/A            N/A
# 97         41 Mott St                 N/A         N/A    N/A            N/A
# 98     83 Chrystie St                 N/A         N/A    N/A            N/A
# 99     112 Stanton St                 N/A         N/A    N/A            N/A
#
#                                                  Tips Agree_Count  \
# 0   Take rice box 2 go - BEST BBQ Roast Pork (beat...           6
# 1   If it’s soft-shell crab season, you know what ...           9
# 2   NYers keep turning out in droves at this nonde...          21
# 3   This 92-year-old Chinatown restaurant serves t...          28
# 4   Go big or go home. $3 for more-than-you-can-ea...          13
# ..                                                ...         ...
# 95                                                            N/A
# 96                                                            N/A
# 97                                                            N/A
# 98                                                            N/A
# 99                                                            N/A
#
#          Polular_Timeframe_Today Latitude Longitude
# 0               10:00 AM–9:00 PM  40.7162  -73.9983
# 1                  Noon–Midnight   40.715  -73.9969
# 2   Noon–3:00 PM5:00 PM–10:00 PM  40.7141  -73.9898
# 3               10:00 AM–9:00 PM  40.7145  -73.9982
# 4               11:00 AM–7:00 PM  40.7173  -73.9942
# ..                           ...      ...       ...
# 95                           N/A      N/A       N/A
# 96                           N/A      N/A       N/A
# 97                           N/A      N/A       N/A
# 98                           N/A      N/A       N/A
# 99                           N/A      N/A       N/A
#
# [100 rows x 13 columns]

# %%
# take out rating=N/A items
df1=df[df['Rating']!='N/A']
df1
# Out:
#                                                  NAME  \
# 0                                    Big Wong King 大旺
# 1                               Great N.Y. Noodletown
# 2                                Mission Chinese Food
# 3                                  Nom Wah Tea Parlor
# 4                   Wah Fung Number 1 Fast Food 華豐快飯店
# 5                                  House Special 甘來飯店
# 6                          Deluxe Green Bo Restaurant
# 7                                             Hop Kee
# 8                                  Congee Village 粥之家
# 9                                Shanghai Café Deluxe
# 10                                        Shanghai 21
# 11                                      Spicy Village
# 12                                 Xi'an Famous Foods
# 13                                  Wo Hop Restaurant
# 14                                 Noodle Village 粥麵軒
# 15                                 Buddha Bodai 佛菩提素菜
# 16                     Golden Unicorn Restaurant 麒麟金閣
# 17                           Yi Ji Shi Mo Noodle Corp
# 18                         Jing Fong Restaurant 金豐大酒樓
# 19                           Vanessa's Dumpling House
# 20                                     Golden Steamer
# 21                            Bo Ky Restaurant 波記潮州小食
# 22                                           Hwa Yuan
# 23                              Kings County Imperial
# 24                                     North Dumpling
# 25                               Green Garden Village
# 26  Shu Jiao Fu Zhou Cuisine 潭頭王福州小吃 (Shu Jiao Fu ...
# 27                               99 Favor Taste 99號餐廳
# 28                                     Famous Sichuan
# 29                Lan Zhou Handmade Noodle & Dumpling
# 30                                         Mei Li Wah
# 31                                  Tai Pan Bakery 大班
# 32                            Bodhi Kosher Vegetarian
# 33                                      Tiny Shanghai
# 34                                       Málà Project
# 35                                        Han Dynasty
# 43  5d9b6bef309f4b000893454d         90 Clinton St                 N/A
# 44  53dbd417498effcb4023b8ce     13 Saint Marks Pl                   2
# 45  3fd66200f964a5209fe61ee3       14 Elizabeth St                   2
# 46  56ddc1f8cd1028ec415bf35a         380 Broome St                 N/A
# 47  4d1f817c16cfb60cb1bd5161        85 Eldridge St                   1
# 48  4ebaf4726d86b14645c49d68         27 Rutgers St                 N/A
#
#    Likes_Count Rating Rating_Signals  \
# 0          422    8.4            646
# 1          547      8            910
# 2          945    8.1           1374
# 3         1258    8.4           1790
# 4          192    8.5            281
# 5           22    8.2             36
# 6          185    8.1            321
# 7          203    7.9            353
# 8          551      8            851
# 9          895    7.9           1337
# 10         741    8.8           1028
# 11         500    8.7            690
# 12         104    8.8            138
# 13         467    7.6            768
# 14         355      8            507
# 15         244    7.9            399
# 16         810    7.7           1188
# 17          19    8.5             24
# 18         999    7.5           1479
# 19        1188    8.2           1674
# 20         101    7.8            166
# 21         137    7.9            227
# 22          68      8             99
# 23          67      9             91
# 24         137    8.4            211
# 25          17      8             21
# 26         245    8.3            356
# 27         466    8.1            656
# 28          52    7.8             89
# 29         151    7.9            215
# 30         256    8.1            408
# 31         224    8.1            339
# 32          72    7.8            109
# 33          46    8.1             64
# 34         436    8.9            550
# 35        1153    8.8           1552
# 36          20      7             41
# 37          24    7.7             32
# 38         325    7.8            467
# 39         243    7.8            361
# 41          80    7.6            130
# 42         200    7.7            315
# 43           6    7.9              8
# 44         668    8.2            957
# 45         191      7            296
# 46         103    7.6            155
# 47          34    7.5             55
# 48           6    7.5             12
#
#                                                  Tips Agree_Count  \
# 0   Take rice box 2 go - BEST BBQ Roast Pork (beat...           6
# 1   If it’s soft-shell crab season, you know what ...           9
# 2   NYers keep turning out in droves at this nonde...          21
# 3   This 92-year-old Chinatown restaurant serves t...          28
# 4   Go big or go home. $3 for more-than-you-can-ea...          13
# 5   Famous for our House Special Chicken - crispy ...           8
# 6   The Shanghainese food here is great. Order the...           5
# 7   Rarely do you return to a childhood spot and n...           3
# 8                Congee village saved my relationship          20
# 9   Soup dumplings are both fascinating and delici...          15
# 10  This place is my new go-to dimsum spot. For a ...           9
# 11  Having studied abroad in Henan province, this ...          11
# 12  staff is cute. food is very delicious. had the...           3
# 13  The egg foo young--a gravied dome of eggs choc...          10
# 14  I'm usually not a big congee fan but I have to...           6
# 15  Best eat in Chinatown. Offer traditional dishe...           1
# 16  Awesome dim sum.  Try to get here by 11 on the...           6
# 17  Super thin and light, just crazy packed. Shrim...           2
# 18  Amazing dim sum! Some of the carts skipped us ...          13
# 19  Vanessa’s is best known for its cheap eponymou...          18
# 20  Seriously the best desserts in the city. How c...           2
# 21  Ask for the Cambodian noodles dry with soup on...           5
# 22  The lingering taste the cold sesame noodles ca...           3
# 23  Delicious and great for a group dinner. Soup d...           3
# 24  Get a #1 and a number #7 (beef noodle soup). H...           3
# 25                                                            N/A
# 26  All the white hipsters go to Vanessa's. All th...          24
# 27  Unlimited hot pot. Lots of options. Great serv...           9
# 35                    Noon–10:00 PM  40.7321  -73.9881
# 36                 3:00 PM–11:00 PM  40.7168  -73.9893
# 37                  9:00 AM–9:00 PM  40.7155  -73.9981
# 38                    Noon–10:00 PM  40.7146  -73.9988
# 39  10:00 AM–4:00 PM6:00 PM–9:00 PM  40.7144  -73.9988
# 41                     Noon–8:00 PM  40.7183  -73.9984
# 42                     Noon–8:00 PM  40.7149  -73.9995
# 43                              N/A  40.7183  -73.9852
# 44                    Noon–10:00 PM  40.7293   -73.989
# 45  10:00 AM–4:00 PM6:00 PM–9:00 PM  40.7159  -73.9973
# 46                     Noon–9:00 PM  40.7205  -73.9964
# 47                             None  40.7173  -73.9924
# 48     Noon–3:00 PM7:00 PM–11:00 PM  40.7129    -73.99

# %%
#sort by rating for next analysis
df2=df1.sort_values(by='Rating', ascending=False)
df2
# Out:
#                                                  NAME  \
# 23                              Kings County Imperial
# 34                                       Málà Project
# 10                                        Shanghai 21
# 35                                        Han Dynasty
# 12                                 Xi'an Famous Foods
# 11                                      Spicy Village
# 4                   Wah Fung Number 1 Fast Food 華豐快飯店
# 17                           Yi Ji Shi Mo Noodle Corp
# 0                                    Big Wong King 大旺
# 24                                     North Dumpling
# 3                                  Nom Wah Tea Parlor
# 26  Shu Jiao Fu Zhou Cuisine 潭頭王福州小吃 (Shu Jiao Fu ...
# 19                           Vanessa's Dumpling House
# 44                                            The Bao
# 5                                  House Special 甘來飯店
# 33                                      Tiny Shanghai
# 30                                         Mei Li Wah
# 31                                  Tai Pan Bakery 大班
# 27                               99 Favor Taste 99號餐廳
# 6                          Deluxe Green Bo Restaurant
# 2                                Mission Chinese Food
# 8                                  Congee Village 粥之家
# 22                                           Hwa Yuan
# 14                                 Noodle Village 粥麵軒
# 1                               Great N.Y. Noodletown
# 25                               Green Garden Village
# 43                                            3 Times
# 9                                Shanghai Café Deluxe
# 29                Lan Zhou Handmade Noodle & Dumpling
# 15                                 Buddha Bodai 佛菩提素菜
# 7                                             Hop Kee
# 21                            Bo Ky Restaurant 波記潮州小食
# 28                                     Famous Sichuan
# 39                                     Ping's Seafood
# 38                                  Peking Duck House
# 32                            Bodhi Kosher Vegetarian
# 20                                     Golden Steamer
# 16                     Golden Unicorn Restaurant 麒麟金閣
# 37                                 Kong Sihk Tong 港食堂
# 42                                     Tasty Dumpling
# 41                        May Wah Pork Chop Fast Food
# 13                                  Wo Hop Restaurant
# 46                                       Mimi Cheng's
# 18                         Jing Fong Restaurant 金豐大酒樓
# 47                                  S.Wan Cafe 洋紫荊咖啡室
# 48                                      Forever Taste
# 36                                      Golden Forest
# 45                            Oriental Garden 福臨門海鮮酒家
#
#                           ID               ADDRESS Category Price_Tier  \
# 23  5b380f649deb7d00399fdf9d   168 1/2 Delancey St                 N/A
# 34  5647ee82498e8bfc0ddef53d           122 1st Ave                   2
# 10  4bcf9774a8b3a5939497625f            21 Mott St                   2
# 35  52169fba11d21db81bdab2a0            90 3rd Ave                   2
# 12  5894c9a15e56b417cf79e553          45 Bayard St                 N/A
# 11  4db3374590a0843f295fb69b  68 Forsyth St Frnt B                   1
# 33          46    8.1             64
# 30         256    8.1            408
# 31         224    8.1            339
# 27         466    8.1            656
# 6          185    8.1            321
# 2          945    8.1           1374
# 8          551      8            851
# 22          68      8             99
# 14         355      8            507
# 1          547      8            910
# 25          17      8             21
# 43           6    7.9              8
# 9          895    7.9           1337
# 29         151    7.9            215
# 15         244    7.9            399
# 7          203    7.9            353
# 21         137    7.9            227
# 28          52    7.8             89
# 39         243    7.8            361
# 38         325    7.8            467
# 32          72    7.8            109
# 20         101    7.8            166
# 16         810    7.7           1188
# 37          24    7.7             32
# 42         200    7.7            315
# 41          80    7.6            130
# 13         467    7.6            768
# 46         103    7.6            155
# 18         999    7.5           1479
# 47          34    7.5             55
# 48           6    7.5             12
# 36          20      7             41
# 45         191      7            296
#
#                                                  Tips Agree_Count  \
# 23  Delicious and great for a group dinner. Soup d...           3
# 34  I could come here just for the Mala peanuts (a...          10
# 10  This place is my new go-to dimsum spot. For a ...           9
# 35  The menu includes things like Dan Dan noodles,...          16
# 12  staff is cute. food is very delicious. had the...           3
# 11  Having studied abroad in Henan province, this ...          11
# 4   Go big or go home. $3 for more-than-you-can-ea...          13
# 17  Super thin and light, just crazy packed. Shrim...           2
# 0   Take rice box 2 go - BEST BBQ Roast Pork (beat...           6
# 24  Get a #1 and a number #7 (beef noodle soup). H...           3
# 3   This 92-year-old Chinatown restaurant serves t...          28
# 26  All the white hipsters go to Vanessa's. All th...          24
# 19  Vanessa’s is best known for its cheap eponymou...          18
# 44  It's a shame they no longer offer soup dumplin...          13
# 5   Famous for our House Special Chicken - crispy ...           8
# 33  The pork and crab Xlb are pretty good. Good cl...           4
# 30  don’t have anything else to add about the bake...           3
# 31  Try to take the attention of some one is a rea...           3
# 27  Unlimited hot pot. Lots of options. Great serv...           9
# 6   The Shanghainese food here is great. Order the...           5
# 2   NYers keep turning out in droves at this nonde...          21
# 8                Congee village saved my relationship          20
# 22  The lingering taste the cold sesame noodles ca...           3
# 14  I'm usually not a big congee fan but I have to...           6
# 1   If it’s soft-shell crab season, you know what ...           9
# 25                                                            N/A
# 43  NYT Hungry City Critic's Pick (2/2020): "Xiao ...           2
# 9   Soup dumplings are both fascinating and delici...          15
# 29  THEY’RE BACK. beef noodle soup, dry noodle wit...          10
# 15  Best eat in Chinatown. Offer traditional dishe...           1
# 7   Rarely do you return to a childhood spot and n...           3
# 21  Ask for the Cambodian noodles dry with soup on...           5
# 28              15% off the bill at weekdays 5pm-11pm           3
# 39  The dim sum is cheap and pretty fresh. Very po...           3
# 38  Whole ducks with perfectly crisp skins are bro...           5
# 32  Very nice vegan and vegetarian spot in Chinato...           5
# 20  Seriously the best desserts in the city. How c...           2
# 16  Awesome dim sum.  Try to get here by 11 on the...           6
# 37  Best HK-style baked spaghetti In NYC! It reall...           1
# 42  Tasty Dumpling's rich pork filling is one of o...           6
# 41  Cheap and tastes good! The fried chicken leg o...           1
# 13  The egg foo young--a gravied dome of eggs choc...          10
# 46  Delicious dumplings and other Taiwanese comfor...           7
# 18  Amazing dim sum! Some of the carts skipped us ...          13
# 34                                       Málà Project
# 10                                        Shanghai 21
# 35                                        Han Dynasty
# 12                                 Xi'an Famous Foods
# 11                                      Spicy Village
# 4                   Wah Fung Number 1 Fast Food 華豐快飯店
# 17                           Yi Ji Shi Mo Noodle Corp
# 0                                    Big Wong King 大旺
# 24                                     North Dumpling
# 3                                  Nom Wah Tea Parlor
# 26  Shu Jiao Fu Zhou Cuisine 潭頭王福州小吃 (Shu Jiao Fu ...
# 19                           Vanessa's Dumpling House
# 44                                            The Bao
# 5                                  House Special 甘來飯店
# 33                                      Tiny Shanghai
# 30                                         Mei Li Wah
# 31                                  Tai Pan Bakery 大班
# 27                               99 Favor Taste 99號餐廳
# 6                          Deluxe Green Bo Restaurant
# 2                                Mission Chinese Food
#
#                           ID               ADDRESS Category Price_Tier  \
# 23  5b380f649deb7d00399fdf9d   168 1/2 Delancey St                 N/A
# 34  5647ee82498e8bfc0ddef53d           122 1st Ave                   2
# 10  4bcf9774a8b3a5939497625f            21 Mott St                   2
# 35  52169fba11d21db81bdab2a0            90 3rd Ave                   2
# 12  5894c9a15e56b417cf79e553          45 Bayard St                 N/A
# 11  4db3374590a0843f295fb69b  68 Forsyth St Frnt B                   1
# 4   4a96bf8ff964a520ce2620e3        79 Chrystie St                   1
# 17  5c965dad5455b2002c058659       88 Elizabeth St                 N/A
# 0   3fd66200f964a520ede41ee3            67 Mott St                   1
# 24  4aca9125f964a52060c220e3           27 Essex St                   1
# 3   49f220a3f964a520ee691fe3          13 Doyers St                   1
# 26  4b391426f964a520ae5525e3       118 Eldridge St                   1
# 19  49eeaf08f964a52078681fe3       118 Eldridge St                   1
# 44  53dbd417498effcb4023b8ce     13 Saint Marks Pl                   2
# 5   59ad625a2619ee5cdded881f         171 Hester St                 N/A
# 33  5a64d9d58ad62e4f602a3e51       112 Mulberry St                 N/A
# 30  49d55b3bf964a5208d5c1fe3       62-64 Bayard St                   1
# 31  49eb223ff964a520a6661fe3          194 Canal St                   1
# 27  530ff20411d2a01b7bb8a19c          285 Grand St                   2
# 6   3fd66200f964a520ceea1ee3          66 Bayard St                   1
# 2   4fa89bb2e4b0bad89524b84a        171 E Broadway                   3
#
#    Likes_Count Rating Rating_Signals  \
# 23          67      9             91
# 34         436    8.9            550
# 10         741    8.8           1028
# 35        1153    8.8           1552
# 12         104    8.8            138
# 11         500    8.7            690
# 4          192    8.5            281
# 17          19    8.5             24
# 0          422    8.4            646
# 24         137    8.4            211
# 3         1258    8.4           1790
# 26         245    8.3            356
# 19        1188    8.2           1674
# 44         668    8.2            957
# 5           22    8.2             36
# 33          46    8.1             64
# 30         256    8.1            408
# 31         224    8.1            339
# 27         466    8.1            656
# 6          185    8.1            321
# 2          945    8.1           1374
#
#                                                  Tips Agree_Count  \
# 23  Delicious and great for a group dinner. Soup d...           3
# 34  I could come here just for the Mala peanuts (a...          10
# 10  This place is my new go-to dimsum spot. For a ...           9
# 35  The menu includes things like Dan Dan noodles,...          16
# 12  staff is cute. food is very delicious. had the...           3
# 11  Having studied abroad in Henan province, this ...          11
# 4   Go big or go home. $3 for more-than-you-can-ea...          13
# 17  Super thin and light, just crazy packed. Shrim...           2
# 0   Take rice box 2 go - BEST BBQ Roast Pork (beat...           6
# 24  Get a #1 and a number #7 (beef noodle soup). H...           3
# 3   This 92-year-old Chinatown restaurant serves t...          28
# 26  All the white hipsters go to Vanessa's. All th...          24
# 19  Vanessa’s is best known for its cheap eponymou...          18
# 44  It's a shame they no longer offer soup dumplin...          13
# 5   Famous for our House Special Chicken - crispy ...           8
# 33  The pork and crab Xlb are pretty good. Good cl...           4
# 30  don’t have anything else to add about the bake...           3
# 31  Try to take the attention of some one is a rea...           3
# 27  Unlimited hot pot. Lots of options. Great serv...           9
# 6   The Shanghainese food here is great. Order the...           5
# 2   NYers keep turning out in droves at this nonde...          21
#
#          Polular_Timeframe_Today Latitude Longitude
# 23  Noon–1:00 PM6:00 PM–10:00 PM  40.7178  -73.9856
# 34  Noon–3:00 PM5:00 PM–10:00 PM  40.7271  -73.9855
# 10              11:00 AM–9:00 PM  40.7144  -73.9989
# 35                 Noon–10:00 PM  40.7321  -73.9881
# 12              11:00 AM–9:00 PM  40.7152  -73.9973
# 11                          None   40.717  -73.9935
# 4               11:00 AM–7:00 PM  40.7173  -73.9942
# 17               8:00 AM–4:00 PM  40.7183  -73.9959
# 0               10:00 AM–9:00 PM  40.7162  -73.9983
# 24                 Noon–10:00 PM  40.7158  -73.9896
# 3               10:00 AM–9:00 PM  40.7145  -73.9982
# 26              11:00 AM–9:00 PM  40.7184  -73.9917
# 19                 Noon–10:00 PM  40.7183  -73.9919
# 44                 Noon–10:00 PM  40.7293   -73.989
# 5                            N/A  40.7178  -73.9968
# 33                  Noon–8:00 PM  40.7179  -73.9981
# 30             10:00 AM–10:00 PM  40.7155   -73.998
# 31              10:00 AM–9:00 PM  40.7169   -73.998
# 27                 Noon–10:00 PM  40.7176  -73.9926
# 6              11:00 AM–10:00 PM  40.7155  -73.9981
# 2   Noon–3:00 PM5:00 PM–10:00 PM  40.7141  -73.9898

# %%
#install and import folium function
#! conda install -c conda-forge folium
import folium 
import webbrowser
from folium.plugins import MarkerCluster

# %%
# create map of New York using latitude and longitude values
# https://python-visualization.github.io/folium/quickstart.html
map_chinatown = folium.Map(location=[latitude, longitude], zoom_start=14)
map_chinatown
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# add markers to map
for name, lat, lng, rating, address,price_tier, Polular_Timeframe_Today in zip(df3['NAME'],df3['Latitude'], df3['Longitude'], df3['Rating'], df3['ADDRESS'],df3['Price_Tier'],df3['Polular_Timeframe_Today']):
    label = 'Rating:{}, Address:{}, Price_Tier:{},\n Avoid Time:{}'.format(rating,address,price_tier,Polular_Timeframe_Today )
    tooltip= '{}'.format(name)
    if price_tier==1 or price_tier==2:
        folium.Marker([lat, lng],popup=label,icon=folium.Icon(color='blue',icon='info-sign'),tooltip=tooltip).add_to(map_chinatown)
    elif price_tier==3 or price_tier==4:
        folium.Marker([lat, lng],popup=label,icon=folium.Icon(color='red',icon='info-sign'),tooltip=tooltip).add_to(map_chinatown)
    else:
        folium.Marker([lat, lng],popup=label,icon=folium.Icon(color='black',icon='info-sign'),tooltip=tooltip).add_to(map_chinatown)
        
map_chinatown
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# add clusters into map
map_chinatown = folium.Map(location=[latitude, longitude], zoom_start=14)

# %%
marker_cluster = folium.plugins.MarkerCluster().add_to(map_chinatown) 
for index, row in df3.iterrows():
    locationlist = row[['Latitude','Longitude']].values.tolist()
    tooltip= '{}'.format(row['NAME'])
    if row['Price_Tier']==1 or row['Price_Tier']==2:
        folium.Marker(location=locationlist, popup='Address:{}, Rating:{}, Price Tier:{},/n Avoid Time:{}'.format(row['ADDRESS'],row['Rating'],row['Price_Tier'],row['Polular_Timeframe_Today']), icon=folium.Icon(color='green', icon='ok-sign'),tooltip=tooltip).add_to(marker_cluster)
    elif row['Price_Tier']==3 or row['Price_Tier']==4:
        folium.Marker(location=locationlist, popup='Address:{}, Rating:{}, Price Tier:{},/n Avoid Time:{}'.format(row['ADDRESS'],row['Rating'],row['Price_Tier'],row['Polular_Timeframe_Today']), icon=folium.Icon(color='red', icon='ok-sign'),tooltip=tooltip).add_to(marker_cluster)
    else:
        folium.Marker(location=locationlist, popup='Address:{}, Rating:{}, Price Tier:{},/n Avoid Time:{}'.format(row['ADDRESS'],row['Rating'],row['Price_Tier'],row['Polular_Timeframe_Today']), icon=folium.Icon(color='black', icon='ok-sign'),tooltip=tooltip).add_to(marker_cluster)
map_chinatown
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Now we have:
# ## 1. A intuitive map with top 20 rating chinese restaurants around Chinatown in NY
# ## 2. If there are more than two restaurants nearby one location, there will be clucters button to zoom in
# ## 3. We can mouseover to those locations to see their names
# ## 4. We can choose different price tiers by looking at their colors, green means cheap, red means a bit expensive, black means we dont have price info of these locations
# ## 5. By clicking those locations we can see details of address,rating,price tier and popular time frame to avoid queuing

# %% [markdown]
# ## Next we can use initial 100 data and KNN clustering means for further analysis

# %%
# let's take a look at the dataframe with 100 rows first --- df1
df1.head(20)
# Out:
#                                  NAME                        ID  \
# 0                    Big Wong King 大旺  3fd66200f964a520ede41ee3
# 1               Great N.Y. Noodletown  3fd66200f964a520b1ea1ee3
# 2                Mission Chinese Food  4fa89bb2e4b0bad89524b84a
# 3                  Nom Wah Tea Parlor  49f220a3f964a520ee691fe3
# 4   Wah Fung Number 1 Fast Food 華豐快飯店  4a96bf8ff964a520ce2620e3
# 5                  House Special 甘來飯店  59ad625a2619ee5cdded881f
# 6          Deluxe Green Bo Restaurant  3fd66200f964a520ceea1ee3
# 7                             Hop Kee  3fd66200f964a5206be61ee3
# 8                  Congee Village 粥之家  425f0400f964a52011211fe3
# 9                Shanghai Café Deluxe  46936ee3f964a520d0481fe3
# 10                        Shanghai 21  4bcf9774a8b3a5939497625f
# 11                      Spicy Village  4db3374590a0843f295fb69b
# 12                 Xi'an Famous Foods  5894c9a15e56b417cf79e553
# 13                  Wo Hop Restaurant  3fd66200f964a52037e31ee3
# 14                 Noodle Village 粥麵軒  49d3deadf964a5201d5c1fe3
# 15                 Buddha Bodai 佛菩提素菜  459b830af964a5208b401fe3
# 16     Golden Unicorn Restaurant 麒麟金閣  3fd66200f964a520ece31ee3
# 17           Yi Ji Shi Mo Noodle Corp  5c965dad5455b2002c058659
# 18         Jing Fong Restaurant 金豐大酒樓  3fd66200f964a520d5e31ee3
# 19           Vanessa's Dumpling House  49eeaf08f964a52078681fe3
#
#                  ADDRESS Category Price_Tier Likes_Count Rating  \
# 0             67 Mott St                   1         422    8.4
# 1              28 Bowery                   1         547      8
# 2         171 E Broadway                   3         945    8.1
# 3           13 Doyers St                   1        1258    8.4
# 4         79 Chrystie St                   1         192    8.5
# 5          171 Hester St                 N/A          22    8.2
# 6           66 Bayard St                   1         185    8.1
# 7             21 Mott St                   2         203    7.9
# 8           100 Allen St                   2         551      8
# 9            100 Mott St                   1         895    7.9
# 10            21 Mott St                   2         741    8.8
# 11  68 Forsyth St Frnt B                   1         500    8.7
# 12          45 Bayard St                 N/A         104    8.8
# 13            17 Mott St                   2         467    7.6
# 14            13 Mott St                   1         355      8
# 15             5 Mott St                   1         244    7.9
# 16         18 E Broadway                   2         810    7.7
# 17       88 Elizabeth St                 N/A          19    8.5
# 18       20 Elizabeth St                   2         999    7.5
# 19       118 Eldridge St                   1        1188    8.2
#
#    Rating_Signals                                               Tips  \
# 0             646  Take rice box 2 go - BEST BBQ Roast Pork (beat...
# 1             910  If it’s soft-shell crab season, you know what ...
# 2            1374  NYers keep turning out in droves at this nonde...
# 3            1790  This 92-year-old Chinatown restaurant serves t...
# 4             281  Go big or go home. $3 for more-than-you-can-ea...
# 5              36  Famous for our House Special Chicken - crispy ...
# 6             321  The Shanghainese food here is great. Order the...
# 7             353  Rarely do you return to a childhood spot and n...
# 8             851               Congee village saved my relationship
# 9            1337  Soup dumplings are both fascinating and delici...
# 10           1028  This place is my new go-to dimsum spot. For a ...
# 11            690  Having studied abroad in Henan province, this ...
# 12            138  staff is cute. food is very delicious. had the...
# 13            768  The egg foo young--a gravied dome of eggs choc...
# 14            507  I'm usually not a big congee fan but I have to...
# 15            399  Best eat in Chinatown. Offer traditional dishe...
# 16           1188  Awesome dim sum.  Try to get here by 11 on the...
# 17             24  Super thin and light, just crazy packed. Shrim...
# 18           1479  Amazing dim sum! Some of the carts skipped us ...
# 19           1674  Vanessa’s is best known for its cheap eponymou...
#
#    Agree_Count       Polular_Timeframe_Today Latitude Longitude
# 0            6              10:00 AM–9:00 PM  40.7162  -73.9983
# 1            9                 Noon–Midnight   40.715  -73.9969
# 2           21  Noon–3:00 PM5:00 PM–10:00 PM  40.7141  -73.9898
# 3           28              10:00 AM–9:00 PM  40.7145  -73.9982
# 4           13              11:00 AM–7:00 PM  40.7173  -73.9942
# 5            8                           N/A  40.7178  -73.9968
# 6            5             11:00 AM–10:00 PM  40.7155  -73.9981
# 7            3                 Noon–10:00 PM  40.7144  -73.9989
# 8           20                 Noon–10:00 PM  40.7187  -73.9905
# 9           15              11:00 AM–9:00 PM  40.7173  -73.9975
# 10           9              11:00 AM–9:00 PM  40.7144  -73.9989
# 11          11                          None   40.717  -73.9935
# 12           3              11:00 AM–9:00 PM  40.7152  -73.9973
# 13          10                           N/A  40.7143  -73.9989
# 14           6             11:00 AM–10:00 PM  40.7141  -73.9987
# 15           1              10:00 AM–9:00 PM  40.7138  -73.9987
# 16           6              10:00 AM–4:00 PM  40.7136  -73.9972
# 17           2               8:00 AM–4:00 PM  40.7183  -73.9959
# 18          13              10:00 AM–4:00 PM  40.7159  -73.9972
# 19          18                 Noon–10:00 PM  40.7183  -73.9919

# %% [markdown]
# ## Pre-processing

# %%
#take out N/A items and columns ID/ADDRESS/TIPS/AGREE COUNT/POPULAR TIMEFRAME/LATTITUDE/LONGITUDE
df4=df1[df1['Price_Tier']!='N/A']
df4=df4.iloc[:,[0,4,5,6,7]]
df4
# Out:
#                                                  NAME Price_Tier Likes_Count  \
# 0                                    Big Wong King 大旺          1         422
# 1                               Great N.Y. Noodletown          1         547
# 2                                Mission Chinese Food          3         945
# 3                                  Nom Wah Tea Parlor          1        1258
# 4                   Wah Fung Number 1 Fast Food 華豐快飯店          1         192
# 6                          Deluxe Green Bo Restaurant          1         185
# 7                                             Hop Kee          2         203
# 8                                  Congee Village 粥之家          2         551
# 9                                Shanghai Café Deluxe          1         895
# 10                                        Shanghai 21          2         741
# 11                                      Spicy Village          1         500
# 13                                  Wo Hop Restaurant          2         467
# 14                                 Noodle Village 粥麵軒          1         355
# 15                                 Buddha Bodai 佛菩提素菜          1         244
# 16                     Golden Unicorn Restaurant 麒麟金閣          2         810
# 18                         Jing Fong Restaurant 金豐大酒樓          2         999
# 19                           Vanessa's Dumpling House          1        1188
# 20                                     Golden Steamer          1         101
# 21                            Bo Ky Restaurant 波記潮州小食          1         137
# 24                                     North Dumpling          1         137
# 26  Shu Jiao Fu Zhou Cuisine 潭頭王福州小吃 (Shu Jiao Fu ...          1         245
# 27                               99 Favor Taste 99號餐廳          2         466
# 28                                     Famous Sichuan          2          52
# 30                                         Mei Li Wah          1         256
# 31                                  Tai Pan Bakery 大班          1         224
# 34                                       Málà Project          2         436
# 35                                        Han Dynasty          2        1153
# 36                                      Golden Forest          1          20
# 38                                  Peking Duck House          2         325
# 39                                     Ping's Seafood          2         243
# 41                        May Wah Pork Chop Fast Food          1          80
# 42                                     Tasty Dumpling          1         200
# 44                                            The Bao          2         668
# 45                            Oriental Garden 福臨門海鮮酒家          2         191
# 47                                  S.Wan Cafe 洋紫荊咖啡室          1          34
#
#    Rating Rating_Signals
# 0     8.4            646
# 1       8            910
# 2     8.1           1374
# 3     8.4           1790
# 4     8.5            281
# 6     8.1            321
# 7     7.9            353
# 8       8            851
# 9     7.9           1337
# 10    8.8           1028
# 11    8.7            690
# 13    7.6            768
# 14      8            507
# 15    7.9            399
# 16    7.7           1188
# 18    7.5           1479
# 19    8.2           1674
# 20    7.8            166
# 21    7.9            227
# 24    8.4            211
# 26    8.3            356
# 27    8.1            656
# 28    7.8             89
# 30    8.1            408
# 31    8.1            339
# 34    8.9            550
# 35    8.8           1552
# 36      7             41
# 38    7.8            467
# 39    7.8            361
# 41    7.6            130
# 42    7.7            315
# 44    8.2            957
# 45      7            296
# 47    7.5             55

# %%
df4.shape
# Out:
# (35, 5)

# %%
from sklearn.preprocessing import StandardScaler

X = df4.values[:,1:]
X = np.nan_to_num(X)
cluster_dataset = StandardScaler().fit_transform(X)
cluster_dataset
# Out:
# array([[-0.8273403 , -0.05733765,  0.88008132, -0.00942921],
#        [-0.8273403 ,  0.30102265, -0.0325956 ,  0.52838487],
#        [ 2.79227353,  1.44204184,  0.19557363,  1.47363386],
#        [-0.8273403 ,  2.33937603,  0.88008132,  2.32109846],
#        [-0.8273403 , -0.7167206 ,  1.10825056, -0.75299791],
#        [-0.8273403 , -0.73678878,  0.19557363, -0.67151093],
#        [ 0.98246661, -0.68518489, -0.26076484, -0.60632135],
#        [ 0.98246661,  0.31249018, -0.0325956 ,  0.40819157],
#        [-0.8273403 ,  1.29869772, -0.26076484,  1.3982584 ],
#        [ 0.98246661,  0.85719784,  1.79275825,  0.76877147],
#        [-0.8273403 ,  0.16627918,  1.56458902,  0.08020647],
#        [ 0.98246661,  0.07167206, -0.94527253,  0.23910609],
#        [-0.8273403 , -0.24941877, -0.0325956 , -0.29259647],
#        [-0.8273403 , -0.56764271, -0.26076484, -0.51261132],
#        [ 0.98246661,  1.05501272, -0.7171033 ,  1.09471939],
#        [ 0.98246661,  1.59685349, -1.17344177,  1.68753718],
#        [-0.8273403 ,  2.13869427,  0.42374286,  2.08478622],
#        [-0.8273403 , -0.9776069 , -0.48893407, -0.98727299],
#        [-0.8273403 , -0.87439913, -0.26076484, -0.86300534],
#        [-0.8273403 , -0.87439913,  0.88008132, -0.89560013],
#        [-0.8273403 , -0.56477583,  0.65191209, -0.60020982],
#        [ 0.98246661,  0.06880518,  0.19557363,  0.01094254],
#        [ 0.98246661, -1.11808413, -0.48893407, -1.14413543],
#        [-0.8273403 , -0.53324013,  0.19557363, -0.49427675],
#        [-0.8273403 , -0.62498036,  0.19557363, -0.63484179],
#        [ 0.98246661, -0.01720129,  2.02092748, -0.20499796],
#        [ 0.98246661,  2.03835338,  1.79275825,  1.83625092],
#        [-0.8273403 , -1.20982437, -2.31428793, -1.2419198 ],
#        [ 0.98246661, -0.33542524, -0.48893407, -0.37408345],
#        [ 0.98246661, -0.5705096 , -0.48893407, -0.59002395],
#        [-0.8273403 , -1.03781143, -0.94527253, -1.06061127],
#        [-0.8273403 , -0.69378554, -0.7171033 , -0.68373398],
#        [ 0.98246661,  0.64791542,  0.42374286,  0.62413207],
#        [ 0.98246661, -0.71958748, -2.31428793, -0.7224403 ],
#        [-0.8273403 , -1.16968802, -1.17344177, -1.21339936]])

# %%
from sklearn.cluster import KMeans

num_clusters = 3

k_means = KMeans(init="k-means++", n_clusters=num_clusters, n_init=12)
k_means.fit(cluster_dataset)
labels = k_means.labels_

print(labels)
# Out:
# [0 0 1 1 0 0 2 2 1 1 0 2 0 0 1 1 1 0 0 0 0 2 2 0 0 2 1 0 2 2 0 0 1 2 0]

# %%
# add clustering labels
df_final=df1[df1['Price_Tier']!='N/A']
df_final["Labels"] = labels
df_final
# Out:
# d:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                                
# 44  53dbd417498effcb4023b8ce     13 Saint Marks Pl                   2
# 45  3fd66200f964a5209fe61ee3       14 Elizabeth St                   2
# 47  4d1f817c16cfb60cb1bd5161        85 Eldridge St                   1
#
#    Likes_Count Rating Rating_Signals  \
# 0          422    8.4            646
# 1          547      8            910
# 2          945    8.1           1374
# 3         1258    8.4           1790
# 4          192    8.5            281
# 6          185    8.1            321
# 7          203    7.9            353
# 8          551      8            851
# 9          895    7.9           1337
# 10         741    8.8           1028
# 11         500    8.7            690
# 13         467    7.6            768
# 14         355      8            507
# 15         244    7.9            399
# 16         810    7.7           1188
# 18         999    7.5           1479
# 19        1188    8.2           1674
# 20         101    7.8            166
# 21         137    7.9            227
# 24         137    8.4            211
# 26         245    8.3            356
# 27         466    8.1            656
# 28          52    7.8             89
# 30         256    8.1            408
# 31         224    8.1            339
# 34         436    8.9            550
# 35        1153    8.8           1552
# 36          20      7             41
# 38         325    7.8            467
# 39         243    7.8            361
# 41          80    7.6            130
# 42         200    7.7            315
# 44         668    8.2            957
# 45         191      7            296
# 47          34    7.5             55
#
#                                                  Tips Agree_Count  \
# 0   Take rice box 2 go - BEST BBQ Roast Pork (beat...           6
# 1   If it’s soft-shell crab season, you know what ...           9
# 2   NYers keep turning out in droves at this nonde...          21
# 3   This 92-year-old Chinatown restaurant serves t...          28
# 4   Go big or go home. $3 for more-than-you-can-ea...          13
# 6   The Shanghainese food here is great. Order the...           5
# 7   Rarely do you return to a childhood spot and n...           3
# 8                Congee village saved my relationship          20
# 9   Soup dumplings are both fascinating and delici...          15
# 10  This place is my new go-to dimsum spot. For a ...           9
# 11  Having studied abroad in Henan province, this ...          11
# 13  The egg foo young--a gravied dome of eggs choc...          10
# 14  I'm usually not a big congee fan but I have to...           6
# 15  Best eat in Chinatown. Offer traditional dishe...           1
# 16  Awesome dim sum.  Try to get here by 11 on the...           6
# 18  Amazing dim sum! Some of the carts skipped us ...          13
# 19  Vanessa’s is best known for its cheap eponymou...          18
# 20  Seriously the best desserts in the city. How c...           2
# 21  Ask for the Cambodian noodles dry with soup on...           5
# 24  Get a #1 and a number #7 (beef noodle soup). H...           3
# 26  All the white hipsters go to Vanessa's. All th...          24
# 27  Unlimited hot pot. Lots of options. Great serv...           9
# 28              15% off the bill at weekdays 5pm-11pm           3
# 30  don’t have anything else to add about the bake...           3
# 31  Try to take the attention of some one is a rea...           3
# 34  I could come here just for the Mala peanuts (a...          10
# 35  The menu includes things like Dan Dan noodles,...          16
# 36  Some of the best American Chinese food I've ev...           2
# 38  Whole ducks with perfectly crisp skins are bro...           5
# 39  The dim sum is cheap and pretty fresh. Very po...           3
# 41  Cheap and tastes good! The fried chicken leg o...           1
# 42  Tasty Dumpling's rich pork filling is one of o...           6
# 44  It's a shame they no longer offer soup dumplin...          13
# 45  David Chang says "the restaurant in Manhattan’...           7
# 47  Hong Kong Milk Tea is a must. Big proportions ...           1
#
#             Polular_Timeframe_Today Latitude Longitude  Labels
# 0                  10:00 AM–9:00 PM  40.7162  -73.9983       0
# 1                     Noon–Midnight   40.715  -73.9969       0
# 2      Noon–3:00 PM5:00 PM–10:00 PM  40.7141  -73.9898       1
# 3                  10:00 AM–9:00 PM  40.7145  -73.9982       1
# 4                  11:00 AM–7:00 PM  40.7173  -73.9942       0
# 6                 11:00 AM–10:00 PM  40.7155  -73.9981       0
# 7                     Noon–10:00 PM  40.7144  -73.9989       2
# 8                     Noon–10:00 PM  40.7187  -73.9905       2
# 9                  11:00 AM–9:00 PM  40.7173  -73.9975       1
# 10                 11:00 AM–9:00 PM  40.7144  -73.9989       1
# 11                             None   40.717  -73.9935       0
# 13                              N/A  40.7143  -73.9989       2
# 14                11:00 AM–10:00 PM  40.7141  -73.9987       0
# 15                 10:00 AM–9:00 PM  40.7138  -73.9987       0
# 16                 10:00 AM–4:00 PM  40.7136  -73.9972       1
# 18                 10:00 AM–4:00 PM  40.7159  -73.9972       1
# 19                    Noon–10:00 PM  40.7183  -73.9919       1
# 20                 10:00 AM–7:00 PM  40.7187  -73.9966       0
# 21                11:00 AM–10:00 PM  40.7157  -73.9987       0
# 24                    Noon–10:00 PM  40.7158  -73.9896       0
# 26                 11:00 AM–9:00 PM  40.7184  -73.9917       0
# 27                    Noon–10:00 PM  40.7176  -73.9926       2
# 28                    Noon–10:00 PM  40.7147  -73.9976       2
# 30                10:00 AM–10:00 PM  40.7155   -73.998       0
# 31                 10:00 AM–9:00 PM  40.7169   -73.998       0
# 34     Noon–3:00 PM5:00 PM–10:00 PM  40.7271  -73.9855       2
# 35                    Noon–10:00 PM  40.7321  -73.9881       1
# 36                 3:00 PM–11:00 PM  40.7168  -73.9893       0
# 38                    Noon–10:00 PM  40.7146  -73.9988       2
# 39  10:00 AM–4:00 PM6:00 PM–9:00 PM  40.7144  -73.9988       2
# 41                     Noon–8:00 PM  40.7183  -73.9984       0
# 42                     Noon–8:00 PM  40.7149  -73.9995       0
# 44                    Noon–10:00 PM  40.7293   -73.989       1
# 45  10:00 AM–4:00 PM6:00 PM–9:00 PM  40.7159  -73.9973       2
# 47                             None  40.7173  -73.9924       0

# %%
# add clusters into map
map_chinatown = folium.Map(location=[latitude, longitude], zoom_start=14)

# %%
marker_cluster = folium.plugins.MarkerCluster().add_to(map_chinatown) 
for index, row in df_final.iterrows():
    locationlist = row[['Latitude','Longitude']].values.tolist()
    tooltip= '{}'.format(row['NAME'])
    if row['Labels']==0:
        folium.Marker(location=locationlist, popup='Rating:{}, Price Tier:{}'.format(row['Rating'],row['Price_Tier']), icon=folium.Icon(color='green', icon='ok-sign'),tooltip=tooltip).add_to(marker_cluster)
    elif row['Price_Tier']==1:
        folium.Marker(location=locationlist, popup='Rating:{}, Price Tier:{}'.format(row['Rating'],row['Price_Tier']), icon=folium.Icon(color='red', icon='ok-sign'),tooltip=tooltip).add_to(marker_cluster)
    else:
        folium.Marker(location=locationlist, popup='Rating:{}, Price Tier:{}'.format(row['Rating'],row['Price_Tier']), icon=folium.Icon(color='black', icon='ok-sign'),tooltip=tooltip).add_to(marker_cluster)
map_chinatown
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Now we can see that green means cluster 0, red means cluster 1, black means cluster 2
